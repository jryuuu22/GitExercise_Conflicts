# %% [markdown]
# <a href="https://colab.research.google.com/github/jryuuu22/GitExercise_Conflicts/blob/main/eclipse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import kagglehub
import os
import re
import optuna
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, average_precision_score, brier_score_loss, confusion_matrix, ConfusionMatrixDisplay

# %%
basketball = kagglehub.dataset_download("wyattowalsh/basketball")
# Out:
# Using Colab cache for faster access to the 'basketball' dataset.

# %%
os.listdir(basketball)
# Out:
# ['nba.sqlite', 'csv']

# %%
csv_path = f"{basketball}/csv"

# %%
print(os.listdir(csv_path))
# Out:
# ['other_stats.csv', 'draft_history.csv', 'team_details.csv', 'player.csv', 'draft_combine_stats.csv', 'team_info_common.csv', 'common_player_info.csv', 'team_history.csv', 'game.csv', 'game_summary.csv', 'officials.csv', 'game_info.csv', 'line_score.csv', 'play_by_play.csv', 'team.csv', 'inactive_players.csv']

# %%
#load dataframe from play_by_play csv
df = pd.read_csv(
    f"{csv_path}/play_by_play.csv", nrows=100000
)

# %%
#filter event by free throw
keyword = "Free Throw"
filtered_df = df[
    df[["homedescription", "visitordescription"]]
    .apply(lambda x: x.astype(str).str.contains(keyword, case=False, na=False))
    .any(axis=1)
]

# %%
filtered_df.head()
# Out:
#      game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 22  29600012        24             3                  11       1     14:54 PM
# 24  29600012        26             3                  12       1     14:54 PM
# 30  29600012        32             3                  11       1     14:56 PM
# 31  29600012        33             3                  12       1     14:56 PM
# 44  29600012        46             3                  11       1     14:58 PM
#
#    pctimestring                     homedescription neutraldescription  \
# 22         9:24                                 NaN                NaN
# 24         9:24                                 NaN                NaN
# 30         8:37  Campbell Free Throw 1 of 2 (1 PTS)                NaN
# 31         8:37     MISS Campbell Free Throw 2 of 2                NaN
# 44         7:23                                 NaN                NaN
#
#                    visitordescription  ... player2_team_nickname  \
# 22  Cassell Free Throw 1 of 2 (1 PTS)  ...                   NaN
# 24  Cassell Free Throw 2 of 2 (2 PTS)  ...                   NaN
# 30                                NaN  ...                   NaN
# 31                                NaN  ...                   NaN
# 44   Person Free Throw 1 of 2 (3 PTS)  ...                   NaN
#
#    player2_team_abbreviation  person3type  player3_id player3_name  \
# 22                       NaN          0.0           0          NaN
# 24                       NaN          0.0           0          NaN
# 30                       NaN          0.0           0          NaN
# 31                       NaN          0.0           0          NaN
# 44                       NaN          0.0           0          NaN
#
#     player3_team_id player3_team_city player3_team_nickname  \
# 22              NaN               NaN                   NaN
# 24              NaN               NaN                   NaN
# 30              NaN               NaN                   NaN
# 31              NaN               NaN                   NaN
# 44              NaN               NaN                   NaN
#
#    player3_team_abbreviation  video_available_flag
# 22                       NaN                     0
# 24                       NaN                     0
# 30                       NaN                     0
# 31                       NaN                     0
# 44                       NaN                     0
#
# [5 rows x 34 columns]

# %%
#Clean dataframe
filtered_df = filtered_df.drop(columns=[
    'neutraldescription', 'video_available_flag',
    'person1type','player1_team_nickname', 'player1_team_abbreviation', 'player1_id', 'player1_name', 'player1_team_city', 'player1_team_id',
    'person2type','player2_team_nickname', 'player2_team_abbreviation', 'player2_id', 'player2_name', 'player2_team_city', 'player2_team_id',
    'person3type','player3_team_nickname', 'player3_team_abbreviation', 'player3_id', 'player3_name', 'player3_team_city', 'player3_team_id'])

# %%
# Combine the home description and visitor description to one index
nan_indices = filtered_df[filtered_df['homedescription'].isna()].index
filtered_df.loc[nan_indices,'homedescription'] = filtered_df.loc[nan_indices,'visitordescription']
filtered_df.head()
# Out:
#      game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 22  29600012        24             3                  11       1     14:54 PM
# 24  29600012        26             3                  12       1     14:54 PM
# 30  29600012        32             3                  11       1     14:56 PM
# 31  29600012        33             3                  12       1     14:56 PM
# 44  29600012        46             3                  11       1     14:58 PM
#
#    pctimestring                     homedescription  \
# 22         9:24   Cassell Free Throw 1 of 2 (1 PTS)
# 24         9:24   Cassell Free Throw 2 of 2 (2 PTS)
# 30         8:37  Campbell Free Throw 1 of 2 (1 PTS)
# 31         8:37     MISS Campbell Free Throw 2 of 2
# 44         7:23    Person Free Throw 1 of 2 (3 PTS)
#
#                    visitordescription  score scoremargin
# 22  Cassell Free Throw 1 of 2 (1 PTS)  1 - 4           3
# 24  Cassell Free Throw 2 of 2 (2 PTS)  2 - 4           2
# 30                                NaN  4 - 5           1
# 31                                NaN    NaN         NaN
# 44   Person Free Throw 1 of 2 (3 PTS)  5 - 9           4

# %%
# Drop unnneeded column
filtered_df = filtered_df.drop(columns=['visitordescription'])
filtered_df.head()
# Out:
#      game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 22  29600012        24             3                  11       1     14:54 PM
# 24  29600012        26             3                  12       1     14:54 PM
# 30  29600012        32             3                  11       1     14:56 PM
# 31  29600012        33             3                  12       1     14:56 PM
# 44  29600012        46             3                  11       1     14:58 PM
#
#    pctimestring                     homedescription  score scoremargin
# 22         9:24   Cassell Free Throw 1 of 2 (1 PTS)  1 - 4           3
# 24         9:24   Cassell Free Throw 2 of 2 (2 PTS)  2 - 4           2
# 30         8:37  Campbell Free Throw 1 of 2 (1 PTS)  4 - 5           1
# 31         8:37     MISS Campbell Free Throw 2 of 2    NaN         NaN
# 44         7:23    Person Free Throw 1 of 2 (3 PTS)  5 - 9           4

# %%
# Rename homedescription with better description
filtered_df.rename(columns={'homedescription': 'FT_Event'}, inplace=True)

# %%
# Check whether each FT attempt is a miss
missed_ft_mask = filtered_df['FT_Event'].str.contains('MISS', case=False, na=False)

filtered_df.loc[:, 'FT_made'] = (~missed_ft_mask).astype(int)

# %%
# Check for Na Values
filtered_df[['score','scoremargin']].isna().sum()
# Out:
# score          3077
# scoremargin    3077
# dtype: int64

# %%
filtered_df.head()
# Out:
#      game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 22  29600012        24             3                  11       1     14:54 PM
# 24  29600012        26             3                  12       1     14:54 PM
# 30  29600012        32             3                  11       1     14:56 PM
# 31  29600012        33             3                  12       1     14:56 PM
# 44  29600012        46             3                  11       1     14:58 PM
#
#    pctimestring                            FT_Event  score scoremargin  \
# 22         9:24   Cassell Free Throw 1 of 2 (1 PTS)  1 - 4           3
# 24         9:24   Cassell Free Throw 2 of 2 (2 PTS)  2 - 4           2
# 30         8:37  Campbell Free Throw 1 of 2 (1 PTS)  4 - 5           1
# 31         8:37     MISS Campbell Free Throw 2 of 2    NaN         NaN
# 44         7:23    Person Free Throw 1 of 2 (3 PTS)  5 - 9           4
#
#     FT_made
# 22        1
# 24        1
# 30        1
# 31        0
# 44        1

# %%
# Create a function to replace Na value in score index
filtered_df = filtered_df.sort_values(['game_id', 'period', 'eventnum'])
filtered_df['score'] = (
    filtered_df.groupby('game_id')['score']
    .ffill()
)

# %%
filtered_df[['score']].isna().sum()
# Out:
# score    93
# dtype: int64

# %%
# With the remaining, we will drop as 93 is insufficient compared to 11k
filtered_df = filtered_df.dropna(subset=['score'])

# %%
# Clean up the score string and split into home / away
score_clean = filtered_df['score'].str.replace(' ', '')

filtered_df['home_score'] = score_clean.str.split('-').str[0].astype(int)
filtered_df['away_score'] = score_clean.str.split('-').str[1].astype(int)

# Define margin as home - away (or away - home if you prefer)
filtered_df['scoremargin'] = filtered_df['home_score'] - filtered_df['away_score']

# %%
filtered_df[['scoremargin','score']].isna().sum()
# Out:
# scoremargin    0
# score          0
# dtype: int64

# %%
filtered_df.head(10)
# Out:
#        game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 2229  29600001         6             3                  10       1
# 2246  29600001        21             3                  10       1
# 2260  29600001        35             3                  16       1
# 2295  29600001        72             3                  11       1
# 2298  29600001        75             3                  12       1
# 2308  29600001        86             3                  11       1
# 2310  29600001        88             3                  12       1
# 2313  29600001        91             3                  11       1
# 2316  29600001        94             3                  12       1
# 2329  29600001       107             3                  11       1
#
#      wctimestring pctimestring                           FT_Event    score  \
# 2229     11:17 PM        11:39   Rodman Free Throw 1 of 1 (3 PTS)    3 - 0
# 2246     11:20 PM         9:06  Ellison Free Throw 1 of 1 (3 PTS)    9 - 7
# 2260     11:23 PM         7:20      MISS Fox Free Throw Technical    9 - 7
# 2295     11:35 PM         2:59   Jordan Free Throw 1 of 2 (5 PTS)  18 - 21
# 2298     11:35 PM         2:59   Jordan Free Throw 2 of 2 (6 PTS)  19 - 21
# 2308     11:37 PM         1:38  MISS Brickowski Free Throw 1 of 2  19 - 21
# 2310     11:38 PM         1:38  MISS Brickowski Free Throw 2 of 2  19 - 21
# 2313     11:38 PM         1:38  MISS Wennington Free Throw 1 of 2  19 - 21
# 2316     11:39 PM         1:38  MISS Wennington Free Throw 2 of 2  19 - 21
# 2329     11:41 PM         0:08       MISS Kukoc Free Throw 1 of 2  19 - 21
#
#       scoremargin  FT_made  home_score  away_score
# 2229            3        1           3           0
# 2246            2        1           9           7
# 2260            2        0           9           7
# 2295           -3        1          18          21
# 2298           -2        1          19          21
# 2308           -2        0          19          21
# 2310           -2        0          19          21
# 2313           -2        0          19          21
# 2316           -2        0          19          21
# 2329           -2        0          19          21

# %%
filtered_df['FT_made'].value_counts()
# Out:
# FT_made
# 1    8301
# 0    2984
# Name: count, dtype: int64

# %%
def extract_player_name(description):
    """Extract player name from free throw description"""
    if pd.isna(description):
        return None
    # Pattern: "PlayerName Free Throw..." or "MISS PlayerName Free Throw..."
    match = re.search(r'^(?:MISS\s+)?([A-Za-z\.\s]+?)\s+Free Throw', str(description))
    return match.group(1).strip() if match else None

filtered_df['player_name'] = filtered_df.apply(
    lambda row: extract_player_name(row['FT_Event']),
    axis=1
)
# Convert pctimestring to seconds remaining
def time_to_seconds(time_str):
    """Convert MM:SS to total seconds"""
    if pd.isna(time_str):
        return None
    try:
        parts = str(time_str).split(':')
        return int(parts[0]) * 60 + int(parts[1])
    except:
        return None

filtered_df['seconds_remaining'] = filtered_df['pctimestring'].apply(time_to_seconds)

# Define clutch situations (last 5 minutes of 4th quarter/OT)
filtered_df['is_clutch'] = (
    (filtered_df['period'] >= 4) &
    (filtered_df['seconds_remaining'] <= 300)
).astype(int)

# Parse score margin (convert "71 - 85" to numeric difference)
def parse_score_margin(score_str):
    """Extract point differential from score string"""
    if pd.isna(score_str):
        return None
    try:
        home, away = score_str.split(' - ')
        return abs(int(home) - int(away))
    except:
        return None

filtered_df['point_differential'] = filtered_df['score'].apply(parse_score_margin)

# High pressure = clutch time AND close game (within 5 points)
filtered_df['high_pressure'] = (
    (filtered_df['is_clutch'] == 1) &
    (filtered_df['point_differential'] <= 5)
).astype(int)

# %%
# Group by player to calculate baseline statistics
player_stats = filtered_df.groupby('player_name').agg({
    'FT_made': ['sum', 'count', 'mean'],
    'is_clutch': 'sum',
    'high_pressure': 'sum'
}).reset_index()

player_stats.columns = ['player_name', 'ft_made_total', 'ft_attempts', 'overall_ft_pct',
                        'clutch_attempts', 'high_pressure_attempts']

# Calculate clutch-specific performance
clutch_stats = filtered_df[filtered_df['is_clutch'] == 1].groupby('player_name').agg({
    'FT_made': 'mean'
}).reset_index()
clutch_stats.columns = ['player_name', 'clutch_ft_pct']

high_pressure_stats = filtered_df[filtered_df['high_pressure'] == 1].groupby('player_name').agg({
    'FT_made': 'mean'
}).reset_index()
high_pressure_stats.columns = ['player_name', 'high_pressure_ft_pct']

# Merge all player statistics
player_stats = player_stats.merge(clutch_stats, on='player_name', how='left')
player_stats = player_stats.merge(high_pressure_stats, on='player_name', how='left')

# Calculate "clutch factor" = clutch FT% - overall FT%
player_stats['clutch_factor'] = player_stats['clutch_ft_pct'] - player_stats['overall_ft_pct']

# Filter for players with meaningful sample size (e.g., at least 20 FT attempts)
player_stats_filtered = player_stats[player_stats['ft_attempts'] >= 20]

print(f"Players with 20+ FT attempts: {len(player_stats_filtered)}")
player_stats_filtered.sort_values('clutch_factor', ascending=False).head(10)
# Out:
# Players with 20+ FT attempts: 172
#     player_name  ft_made_total  ft_attempts  overall_ft_pct  clutch_attempts  \
# 66        Divac             24           37        0.648649                3
# 156    Mashburn             13           20        0.650000                4
# 266      Vaughn             16           24        0.666667                2
# 267      Vaught             22           33        0.666667                2
# 100       Green             25           37        0.675676                2
# 204     Perkins             37           50        0.740000                2
# 60        Davis             49           81        0.604938               22
# 98     Goldwire             19           25        0.760000                7
# 38     Campbell             48           62        0.774194                8
# 10       Austin             25           42        0.595238                5
#
#      high_pressure_attempts  clutch_ft_pct  high_pressure_ft_pct  \
# 66                        0       1.000000                   NaN
# 156                       4       1.000000                   1.0
# 266                       0       1.000000                   NaN
# 267                       0       1.000000                   NaN
# 100                       0       1.000000                   NaN
# 204                       2       1.000000                   1.0
# 60                        2       0.863636                   1.0
# 98                        4       1.000000                   1.0
# 38                        4       1.000000                   1.0
# 10                        2       0.800000                   0.5
#
#      clutch_factor
# 66        0.351351
# 156       0.350000
# 266       0.333333
# 267       0.333333
# 100       0.324324
# 204       0.260000
# 60        0.258698
# 98        0.240000
# 38        0.225806
# 10        0.204762

# %%
player_stats_filtered.sort_values('clutch_factor').head()
# Out:
#     player_name  ft_made_total  ft_attempts  overall_ft_pct  clutch_attempts  \
# 7         Askew             21           28        0.750000                2
# 276      Wesley             16           24        0.666667                2
# 277        West             22           28        0.785714                3
# 235     Russell             28           41        0.682927                3
# 150     Maloney             20           29        0.689655               10
#
#      high_pressure_attempts  clutch_ft_pct  high_pressure_ft_pct  \
# 7                         0       0.000000                   NaN
# 276                       0       0.000000                   NaN
# 277                       2       0.333333                   0.5
# 235                       0       0.333333                   NaN
# 150                       1       0.400000                   1.0
#
#      clutch_factor
# 7        -0.750000
# 276      -0.666667
# 277      -0.452381
# 235      -0.349593
# 150      -0.289655

# %%
#Compute Season Ft% for each player
season_ft = (
    filtered_df.groupby('player_name')['FT_made']
    .mean()
    .reset_index()
    .rename(columns={'FT_made': 'season_FT_pct'})
)

# %%
#merge it back into main DF
filtered_df = filtered_df.merge(season_ft, on='player_name', how='left')

# %%
#Cluth vs Non-Clutch FT%
clutch_ft = filtered_df.groupby('is_clutch')['FT_made'].mean().reset_index()

plt.figure(figsize=(8,5))
sns.barplot(data=clutch_ft, x='is_clutch', y='FT_made')
plt.title("Clutch vs Non-Clutch Free Throw Percentage")
plt.xticks([0,1], ['Non-Clutch', 'Clutch'])
plt.ylabel("FT%")
plt.ylim(0, 1)
plt.show()

# %%
period_ft = filtered_df.groupby('period')['FT_made'].mean().reset_index()

plt.figure(figsize=(8,5))
sns.barplot(data=period_ft, x='period', y='FT_made')
plt.title("Free Throw Percentage by Period")
plt.ylabel("FT%")
plt.xlabel("Period")
plt.ylim(0, 1)
plt.show()

# %%
df_skill = filtered_df.dropna(subset=['season_FT_pct']).copy()

# Create skill tier buckets using quartiles
df_skill['skill_bucket'] = pd.qcut(
    df_skill['season_FT_pct'],
    q=4,
    labels=['Low', 'Mid-Low', 'Mid-High', 'High']
)

# Compute FT% within each bucket
skill_ft = (
    df_skill.groupby('skill_bucket',observed=True)['FT_made']
    .mean()
    .reset_index()
)

# Plot
plt.figure(figsize=(8,5))
sns.barplot(data=skill_ft, x='skill_bucket', y='FT_made')

plt.title("Free Throw Percentage by Player Skill Level")
plt.xlabel("Player Skill Tier (based on season FT%)")
plt.ylabel("FT%")
plt.ylim(0, 1)

plt.show()

# %%
filtered_df = filtered_df.merge(
    player_stats[['player_name', 'overall_ft_pct', 'clutch_ft_pct', 'clutch_factor']],
    on='player_name',
    how='left'
)

print("Added player stats to main dataframe")
print(f"Shape: {filtered_df.shape}")
filtered_df[['player_name', 'overall_ft_pct', 'clutch_ft_pct', 'FT_made']].head()
# Out:
# Added player stats to main dataframe
# Shape: (11285, 22)
#   player_name  overall_ft_pct  clutch_ft_pct  FT_made
# 0      Rodman        0.631579            0.5        1
# 1     Ellison        0.600000            0.5        1
# 2         Fox        0.800000            1.0        0
# 3      Jordan        0.833333            0.9        1
# 4      Jordan        0.833333            0.9        1

# %%
filtered_df['close_game'] = (filtered_df['point_differential'] <= 3).astype(int)

print("Close game distribution:")
print(filtered_df['close_game'].value_counts())
# Out:
# Close game distribution:
# close_game
# 0    8001
# 1    3284
# Name: count, dtype: int64

# %%
filtered_df['late_game'] = (filtered_df['period'] >= 4).astype(int)

print("Late game distribution:")
print(filtered_df['late_game'].value_counts())
# Out:
# Late game distribution:
# late_game
# 0    7568
# 1    3717
# Name: count, dtype: int64

# %%
filtered_df['pressure_score'] = (
    filtered_df['is_clutch'].astype(int) +
    filtered_df['close_game'].astype(int) +
    (filtered_df['seconds_remaining'] <= 120).astype(int)
)
# Score of 3 = clutch time + close game + under 2 minutes (maximum pressure)
# Score of 0 = none of these factors (low pressure)
print("Pressure score distribution:")
print(filtered_df['pressure_score'].value_counts().sort_index())
pressure_performance = filtered_df.groupby('pressure_score')['FT_made'].mean().reset_index()
plt.figure(figsize=(8,5))
sns.barplot(data=pressure_performance, x='pressure_score', y='FT_made')
plt.title("Free Throw % by Pressure Score")
plt.xlabel("Pressure Score (0=low, 3=high)")
plt.ylabel("FT%")
plt.ylim(0, 1)
plt.show()
# Out:
# Pressure score distribution:
# pressure_score
# 0    4901
# 1    4211
# 2    1861
# 3     312
# Name: count, dtype: int64

# %%
career_attempts = filtered_df.groupby('player_name').size().to_dict()
filtered_df['career_attempts_so_far'] = filtered_df['player_name'].map(career_attempts)

print(f"Career attempts range: {filtered_df['career_attempts_so_far'].min()} to {filtered_df['career_attempts_so_far'].max()}")
# Out:
# Career attempts range: 1.0 to 192.0

# %%
player_stats.head()
# Out:
#   player_name  ft_made_total  ft_attempts  overall_ft_pct  clutch_attempts  \
# 0    A. Davis             31           51        0.607843                5
# 1   Alexander              7           12        0.583333                6
# 2       Allen             35           48        0.729167               13
# 3      Alston              0            2        0.000000                2
# 4    Anderson            106          149        0.711409               40
#
#    high_pressure_attempts  clutch_ft_pct  high_pressure_ft_pct  clutch_factor
# 0                       3       0.400000              0.333333      -0.207843
# 1                       0       0.833333                   NaN       0.250000
# 2                       8       0.692308              0.625000      -0.036859
# 3                       0       0.000000                   NaN       0.000000
# 4                      19       0.600000              0.578947      -0.111409

# %%
# Create a feature column
feature_cols = [
    # player features
    'season_FT_pct',
    'overall_ft_pct',
    'clutch_ft_pct',
    'clutch_factor',
    'career_attempts_so_far',
    #pressure/context
    'period',
    'seconds_remaining',
    'is_clutch',
    'close_game',
    'late_game',
    'pressure_score',
    'point_differential'
]


# create df where we have all needed values
model_df = filtered_df[feature_cols+['FT_made', 'game_id']].copy()
model_df = model_df.dropna(subset=['FT_made', 'game_id'])


X = model_df[feature_cols].copy()
y = model_df['FT_made'].copy()

# Get the unique game IDS
game_ids = model_df['game_id'].unique()

# Split game_ids into train and test
train_games, test_games = train_test_split(game_ids, test_size=0.2, shuffle=False)

train_mask = model_df['game_id'].isin(train_games)
test_mask = model_df['game_id'].isin(test_games)

X_train = X[train_mask].copy()
X_test  = X[test_mask].copy()
y_train = y[train_mask].copy()
y_test  = y[test_mask].copy()

# Impute missing values
imputer = SimpleImputer(strategy='median')

X_train_imputed = pd.DataFrame(
    imputer.fit_transform(X_train),
    columns=X_train.columns,
    index=X_train.index
)

X_test_imputed = pd.DataFrame(
    imputer.fit_transform(X_test),
    columns=X_test.columns,
    index=X_test.index
)

# Scale with StandardScaler
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(
    scaler.fit_transform(X_train_imputed),
    columns=X_train_imputed.columns,
    index=X_train_imputed.index
)

X_test_scaled = pd.DataFrame(
    scaler.transform(X_test_imputed),
    columns=X_test_imputed.columns,
    index=X_test_imputed.index
)

# Save CSVs
X_train_scaled.to_csv("X_train.csv", index=False)
X_test_scaled.to_csv("X_test.csv", index=False)
y_train.to_csv("y_train.csv", index=False)
y_test.to_csv("y_test.csv", index=False)

# %%
# Split training/validation data
X_tr, X_val, y_tr, y_val = train_test_split(
    X_train_scaled,
    y_train,
    test_size=0.2,
    stratify=y_train,
    random_state = 42
)

# Logistic Regression
def logreg(trial):
  params = {
      "C": trial.suggest_float("C", 1e-3, 100.0, log=True),
      "penalty": "l2",
      "solver": trial.suggest_categorical("solver", ["lbfgs", "liblinear"]),
      "max_iter": trial.suggest_int("max_iter", 200, 1000),
      'random_state': 42
  }

  model=LogisticRegression(**params)
  model.fit(X_tr, y_tr)
  y_proba = model.predict_proba(X_val)[:,1]

  pr_auc = average_precision_score(y_val, y_proba)
  return pr_auc

#Random Forest Object
def rf(trial):
  params = {
      'n_estimators': trial.suggest_int('n_estimators', 100, 600),
      'max_depth': trial.suggest_int('max_depth', 2, 20),
      'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
      'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
      'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2']),
      'random_state': 42
      }

  model = RandomForestClassifier(**params)
  model.fit(X_tr, y_tr)
  y_proba = model.predict_proba(X_val)[:,1]

  pr_auc = average_precision_score(y_val, y_proba)
  return pr_auc

#XG Boost Objective
def xgb(trial):
  params = {
      'n_estimators': trial.suggest_int('n_estimators', 100, 600),
      'max_depth': trial.suggest_int('max_depth', 2, 20),
      'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.3, log=True),
      'subsample': trial.suggest_float('subsample', 0.5, 1.0),
      'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
      'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
      'objective': 'binary:logistic',
      'eval_metric': 'logloss',
      'random_state': 42
      }
  model = XGBClassifier(**params)
  model.fit(X_tr, y_tr)
  y_proba = model.predict_proba(X_val)[:,1]

  pr_auc = average_precision_score(y_val, y_proba)
  return pr_auc

# %%
#Logistic Regressing tuning
study_logreg = optuna.create_study(direction='maximize', study_name='logreg_pr_auc')
study_logreg.optimize(logreg, n_trials=30)

#Random Forest tuning
study_rf = optuna.create_study(direction='maximize', study_name='rf_pr_auc')
study_rf.optimize(rf, n_trials=30)

#XBG Tuning
study_xgb = optuna.create_study(direction='maximize', study_name='xgb_pr_auc')
study_xgb.optimize(xgb, n_trials=30)
# Out:
# [I 2025-11-23 08:50:16,107] A new study created in memory with name: logreg_pr_auc
# [I 2025-11-23 08:50:16,130] Trial 0 finished with value: 0.8253722897464718 and parameters: {'C': 0.003672398151754301, 'solver': 'lbfgs', 'max_iter': 666}. Best is trial 0 with value: 0.8253722897464718.
# [I 2025-11-23 08:50:16,155] Trial 1 finished with value: 0.8244289694167743 and parameters: {'C': 23.904158821561836, 'solver': 'lbfgs', 'max_iter': 387}. Best is trial 0 with value: 0.8253722897464718.
# [I 2025-11-23 08:50:16,182] Trial 2 finished with value: 0.8255697492340907 and parameters: {'C': 0.0030394460773662457, 'solver': 'liblinear', 'max_iter': 806}. Best is trial 2 with value: 0.8255697492340907.
# [I 2025-11-23 08:50:16,214] Trial 3 finished with value: 0.8244519138458029 and parameters: {'C': 26.152483220486605, 'solver': 'liblinear', 'max_iter': 774}. Best is trial 2 with value: 0.8255697492340907.
# [I 2025-11-23 08:50:16,237] Trial 4 finished with value: 0.824456690245035 and parameters: {'C': 0.18225639592824824, 'solver': 'lbfgs', 'max_iter': 999}. Best is trial 2 with value: 0.8255697492340907.
# [I 2025-11-23 08:50:16,270] Trial 5 finished with value: 0.8244519138458029 and parameters: {'C': 30.817520385748033, 'solver': 'liblinear', 'max_iter': 848}. Best is trial 2 with value: 0.8255697492340907.
# [I 2025-11-23 08:50:16,301] Trial 6 finished with value: 0.8244617891617357 and parameters: {'C': 1.0169367339308872, 'solver': 'liblinear', 'max_iter': 444}. Best is trial 2 with value: 0.8255697492340907.
# [I 2025-11-23 08:50:16,328] Trial 7 finished with value: 0.825109906536423 and parameters: {'C': 0.005239263184232982, 'solver': 'liblinear', 'max_iter': 233}. Best is trial 2 with value: 0.8255697492340907.
# [I 2025-11-23 08:50:16,345] Trial 8 finished with value: 0.82580134437903 and parameters: {'C': 0.0010382244574413614, 'solver': 'lbfgs', 'max_iter': 981}. Best is trial 8 with value: 0.82580134437903.
# [I 2025-11-23 08:50:16,377] Trial 9 finished with value: 0.8244517700391695 and parameters: {'C': 11.265577893107821, 'solver': 'liblinear', 'max_iter': 268}. Best is trial 8 with value: 0.82580134437903.
# [I 2025-11-23 08:50:16,412] Trial 10 finished with value: 0.8245659574280998 and parameters: {'C': 0.04851962745093748, 'solver': 'lbfgs', 'max_iter': 1000}. Best is trial 8 with value: 0.82580134437903.
# [I 2025-11-23 08:50:16,439] Trial 11 finished with value: 0.8258287942633964 and parameters: {'C': 0.0012378259508407314, 'solver': 'lbfgs', 'max_iter': 847}. Best is trial 11 with value: 0.8258287942633964.
# [I 2025-11-23 08:50:16,465] Trial 12 finished with value: 0.8258519280489738 and parameters: {'C': 0.0012842294231346226, 'solver': 'lbfgs', 'max_iter': 899}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,504] Trial 13 finished with value: 0.8246537355278223 and parameters: {'C': 0.023937017278627553, 'solver': 'lbfgs', 'max_iter': 644}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,551] Trial 14 finished with value: 0.8246307878831892 and parameters: {'C': 0.020672183667822138, 'solver': 'lbfgs', 'max_iter': 875}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,577] Trial 15 finished with value: 0.8258356692065634 and parameters: {'C': 0.0010968686356954659, 'solver': 'lbfgs', 'max_iter': 555}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,609] Trial 16 finished with value: 0.824435935486378 and parameters: {'C': 1.7371071783616707, 'solver': 'lbfgs', 'max_iter': 520}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,641] Trial 17 finished with value: 0.8244665861008896 and parameters: {'C': 0.1470722012332457, 'solver': 'lbfgs', 'max_iter': 609}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,672] Trial 18 finished with value: 0.8248132131445847 and parameters: {'C': 0.01019433703268403, 'solver': 'lbfgs', 'max_iter': 725}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,704] Trial 19 finished with value: 0.8245783257910655 and parameters: {'C': 0.05741176267937477, 'solver': 'lbfgs', 'max_iter': 549}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,738] Trial 20 finished with value: 0.8244482932673021 and parameters: {'C': 1.1332952353620427, 'solver': 'lbfgs', 'max_iter': 369}. Best is trial 12 with value: 0.8258519280489738.
# [I 2025-11-23 08:50:16,766] Trial 21 finished with value: 0.825861926353544 and parameters: {'C': 0.0013545772546022356, 'solver': 'lbfgs', 'max_iter': 905}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:16,794] Trial 22 finished with value: 0.8257493268997691 and parameters: {'C': 0.0019365229797118923, 'solver': 'lbfgs', 'max_iter': 915}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:16,827] Trial 23 finished with value: 0.8249169343927418 and parameters: {'C': 0.007292010086505703, 'solver': 'lbfgs', 'max_iter': 712}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:16,857] Trial 24 finished with value: 0.8257965678382939 and parameters: {'C': 0.0010353541137981643, 'solver': 'lbfgs', 'max_iter': 523}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:16,889] Trial 25 finished with value: 0.8247207924107818 and parameters: {'C': 0.01262650477289108, 'solver': 'lbfgs', 'max_iter': 919}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:16,917] Trial 26 finished with value: 0.8255088192516119 and parameters: {'C': 0.0033041358740172303, 'solver': 'lbfgs', 'max_iter': 763}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:16,948] Trial 27 finished with value: 0.8256025789367503 and parameters: {'C': 0.0025285729566886057, 'solver': 'lbfgs', 'max_iter': 474}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:16,982] Trial 28 finished with value: 0.8244310892527702 and parameters: {'C': 88.48895124416944, 'solver': 'lbfgs', 'max_iter': 586}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:17,011] Trial 29 finished with value: 0.8252933080271388 and parameters: {'C': 0.0042684387219346365, 'solver': 'lbfgs', 'max_iter': 682}. Best is trial 21 with value: 0.825861926353544.
# [I 2025-11-23 08:50:17,014] A new study created in memory with name: rf_pr_auc
# [I 2025-11-23 08:50:20,467] Trial 0 finished with value: 0.8220491690736322 and parameters: {'n_estimators': 460, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': 'log2'}. Best is trial 0 with value: 0.8220491690736322.
# [I 2025-11-23 08:50:22,347] Trial 1 finished with value: 0.8214200526215982 and parameters: {'n_estimators': 554, 'max_depth': 2, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8220491690736322.
# [I 2025-11-23 08:50:24,116] Trial 2 finished with value: 0.8159034441130006 and parameters: {'n_estimators': 144, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8220491690736322.
# [I 2025-11-23 08:50:26,096] Trial 3 finished with value: 0.8277452104851277 and parameters: {'n_estimators': 281, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 17, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:31,179] Trial 4 finished with value: 0.809248210333637 and parameters: {'n_estimators': 573, 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:33,375] Trial 5 finished with value: 0.8252176459850284 and parameters: {'n_estimators': 352, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 12, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:35,116] Trial 6 finished with value: 0.818474303300952 and parameters: {'n_estimators': 204, 'max_depth': 19, 'min_samples_split': 20, 'min_samples_leaf': 16, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:37,744] Trial 7 finished with value: 0.8233128746677003 and parameters: {'n_estimators': 273, 'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:41,491] Trial 8 finished with value: 0.8220807660438922 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:45,019] Trial 9 finished with value: 0.8221341662629019 and parameters: {'n_estimators': 472, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:46,157] Trial 10 finished with value: 0.8212070264899467 and parameters: {'n_estimators': 345, 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 19, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:48,114] Trial 11 finished with value: 0.8269882591386051 and parameters: {'n_estimators': 350, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:50,629] Trial 12 finished with value: 0.8269764111278723 and parameters: {'n_estimators': 352, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:52,696] Trial 13 finished with value: 0.8229588136705228 and parameters: {'n_estimators': 268, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:54,770] Trial 14 finished with value: 0.8274017368804458 and parameters: {'n_estimators': 401, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:56,895] Trial 15 finished with value: 0.8273827441195654 and parameters: {'n_estimators': 417, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 16, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:58,470] Trial 16 finished with value: 0.8250001629698792 and parameters: {'n_estimators': 251, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:50:59,447] Trial 17 finished with value: 0.819410280720717 and parameters: {'n_estimators': 120, 'max_depth': 14, 'min_samples_split': 15, 'min_samples_leaf': 16, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:02,081] Trial 18 finished with value: 0.8273777912693616 and parameters: {'n_estimators': 406, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:03,992] Trial 19 finished with value: 0.8141459208738377 and parameters: {'n_estimators': 181, 'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:06,620] Trial 20 finished with value: 0.814823003809216 and parameters: {'n_estimators': 308, 'max_depth': 12, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:08,459] Trial 21 finished with value: 0.8271734894569658 and parameters: {'n_estimators': 408, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 16, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:11,089] Trial 22 finished with value: 0.8236561915780163 and parameters: {'n_estimators': 397, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 15, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:12,826] Trial 23 finished with value: 0.825297134908973 and parameters: {'n_estimators': 447, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:16,601] Trial 24 finished with value: 0.8271443000353575 and parameters: {'n_estimators': 514, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 15, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:18,684] Trial 25 finished with value: 0.8235677193804352 and parameters: {'n_estimators': 309, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 11, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:21,076] Trial 26 finished with value: 0.82769965823841 and parameters: {'n_estimators': 427, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:22,650] Trial 27 finished with value: 0.8249104066000615 and parameters: {'n_estimators': 221, 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:23,888] Trial 28 finished with value: 0.8246747637026101 and parameters: {'n_estimators': 311, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 20, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:28,107] Trial 29 finished with value: 0.8188459918622839 and parameters: {'n_estimators': 447, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 14, 'max_features': 'log2'}. Best is trial 3 with value: 0.8277452104851277.
# [I 2025-11-23 08:51:28,109] A new study created in memory with name: xgb_pr_auc
# [I 2025-11-23 08:51:28,798] Trial 0 finished with value: 0.8149099584190035 and parameters: {'n_estimators': 529, 'max_depth': 4, 'learning_rate': 0.05232031451727869, 'subsample': 0.6861371682966375, 'colsample_bytree': 0.7152880903915643, 'reg_lambda': 0.002344580168305342}. Best is trial 0 with value: 0.8149099584190035.
# [I 2025-11-23 08:51:29,184] Trial 1 finished with value: 0.8270781856613414 and parameters: {'n_estimators': 498, 'max_depth': 3, 'learning_rate': 0.0020440367046192067, 'subsample': 0.9078133482574786, 'colsample_bytree': 0.5366175932226083, 'reg_lambda': 1.316004488251892}. Best is trial 1 with value: 0.8270781856613414.
# [I 2025-11-23 08:51:31,141] Trial 2 finished with value: 0.8010065597971121 and parameters: {'n_estimators': 202, 'max_depth': 12, 'learning_rate': 0.012842982841330558, 'subsample': 0.6566824656922507, 'colsample_bytree': 0.7989941846364714, 'reg_lambda': 0.505321453360654}. Best is trial 1 with value: 0.8270781856613414.
# [I 2025-11-23 08:51:32,266] Trial 3 finished with value: 0.8127002037813802 and parameters: {'n_estimators': 526, 'max_depth': 6, 'learning_rate': 0.020291922890986212, 'subsample': 0.758584525259403, 'colsample_bytree': 0.8966587534178383, 'reg_lambda': 0.02844864514929258}. Best is trial 1 with value: 0.8270781856613414.
# [I 2025-11-23 08:51:34,468] Trial 4 finished with value: 0.7843507771402226 and parameters: {'n_estimators': 259, 'max_depth': 19, 'learning_rate': 0.05105794492127939, 'subsample': 0.858219881733232, 'colsample_bytree': 0.690333368944428, 'reg_lambda': 0.0011691500546898539}. Best is trial 1 with value: 0.8270781856613414.
# [I 2025-11-23 08:51:34,601] Trial 5 finished with value: 0.8309305917187679 and parameters: {'n_estimators': 159, 'max_depth': 3, 'learning_rate': 0.03629251138591226, 'subsample': 0.6827678253594818, 'colsample_bytree': 0.6827280108332846, 'reg_lambda': 0.0070974130672716565}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:36,125] Trial 6 finished with value: 0.7924706129692298 and parameters: {'n_estimators': 587, 'max_depth': 9, 'learning_rate': 0.02609053632087034, 'subsample': 0.5999092910705589, 'colsample_bytree': 0.5936720502187984, 'reg_lambda': 0.04341738276530468}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:38,240] Trial 7 finished with value: 0.8083723289535437 and parameters: {'n_estimators': 194, 'max_depth': 17, 'learning_rate': 0.001051920152728496, 'subsample': 0.9364401469797695, 'colsample_bytree': 0.948133213693339, 'reg_lambda': 2.700773563767612}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:43,052] Trial 8 finished with value: 0.7990309928066839 and parameters: {'n_estimators': 353, 'max_depth': 12, 'learning_rate': 0.0016102171915677518, 'subsample': 0.9289743655785299, 'colsample_bytree': 0.7062959599664074, 'reg_lambda': 0.2411378932103182}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:44,189] Trial 9 finished with value: 0.7810216064072741 and parameters: {'n_estimators': 582, 'max_depth': 8, 'learning_rate': 0.12723194744046487, 'subsample': 0.8330512329137394, 'colsample_bytree': 0.5134659256474494, 'reg_lambda': 0.03915467476785265}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:44,293] Trial 10 finished with value: 0.8220003705666401 and parameters: {'n_estimators': 104, 'max_depth': 2, 'learning_rate': 0.2503858486725954, 'subsample': 0.515380085568633, 'colsample_bytree': 0.8269956564279864, 'reg_lambda': 0.006378931772306223}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:44,548] Trial 11 finished with value: 0.8264449833457961 and parameters: {'n_estimators': 409, 'max_depth': 2, 'learning_rate': 0.00618793155760944, 'subsample': 0.7688546590082579, 'colsample_bytree': 0.5939140350491938, 'reg_lambda': 9.118321752339433}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:45,275] Trial 12 finished with value: 0.8214541411641361 and parameters: {'n_estimators': 434, 'max_depth': 6, 'learning_rate': 0.004171352742326986, 'subsample': 0.9783042386106955, 'colsample_bytree': 0.503242304423186, 'reg_lambda': 1.6883734420523344}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:48,780] Trial 13 finished with value: 0.7947129329930279 and parameters: {'n_estimators': 279, 'max_depth': 15, 'learning_rate': 0.0033202811985826516, 'subsample': 0.8398910070572227, 'colsample_bytree': 0.6199964438049343, 'reg_lambda': 0.005851298534022499}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:48,942] Trial 14 finished with value: 0.8264832720982729 and parameters: {'n_estimators': 111, 'max_depth': 5, 'learning_rate': 0.052254634175248435, 'subsample': 0.6873231247594086, 'colsample_bytree': 0.6346170370991904, 'reg_lambda': 0.19328329159769095}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:50,186] Trial 15 finished with value: 0.8113592269203707 and parameters: {'n_estimators': 443, 'max_depth': 9, 'learning_rate': 0.008790771775395, 'subsample': 0.5809513457495085, 'colsample_bytree': 0.549046166262713, 'reg_lambda': 1.0567104875675761}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:50,404] Trial 16 finished with value: 0.8255249500489165 and parameters: {'n_estimators': 336, 'max_depth': 2, 'learning_rate': 0.002440957749273381, 'subsample': 0.7947187889371704, 'colsample_bytree': 0.7822157561578971, 'reg_lambda': 0.008827258015913893}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:50,830] Trial 17 finished with value: 0.82846947232363 and parameters: {'n_estimators': 480, 'max_depth': 4, 'learning_rate': 0.02991863675649512, 'subsample': 0.8958404063877085, 'colsample_bytree': 0.6565785504881307, 'reg_lambda': 6.225515056490907}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:52,412] Trial 18 finished with value: 0.7981801194786294 and parameters: {'n_estimators': 370, 'max_depth': 8, 'learning_rate': 0.09580943268603961, 'subsample': 0.9912643933135263, 'colsample_bytree': 0.6575978783042261, 'reg_lambda': 6.677452476901112}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:53,437] Trial 19 finished with value: 0.818476739078661 and parameters: {'n_estimators': 175, 'max_depth': 6, 'learning_rate': 0.029358263645234906, 'subsample': 0.7008026717919907, 'colsample_bytree': 0.74414802041544, 'reg_lambda': 0.016516679698899507}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:55,961] Trial 20 finished with value: 0.7964562466141734 and parameters: {'n_estimators': 274, 'max_depth': 14, 'learning_rate': 0.01160618034845638, 'subsample': 0.6188095887883984, 'colsample_bytree': 0.8912861978363913, 'reg_lambda': 0.07204450162304617}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:56,362] Trial 21 finished with value: 0.8261945456789421 and parameters: {'n_estimators': 486, 'max_depth': 4, 'learning_rate': 0.035246379410067835, 'subsample': 0.905736194212351, 'colsample_bytree': 0.5703968063641697, 'reg_lambda': 4.458469586182493}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:57,598] Trial 22 finished with value: 0.8121633903145653 and parameters: {'n_estimators': 495, 'max_depth': 4, 'learning_rate': 0.08687680406442153, 'subsample': 0.8802097882289406, 'colsample_bytree': 0.6713235523608936, 'reg_lambda': 0.6244420315101605}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:57,933] Trial 23 finished with value: 0.8301099597032291 and parameters: {'n_estimators': 467, 'max_depth': 3, 'learning_rate': 0.015357872532779052, 'subsample': 0.727400587147456, 'colsample_bytree': 0.5445576686532724, 'reg_lambda': 2.5987417125839354}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:51:59,350] Trial 24 finished with value: 0.8193886841361687 and parameters: {'n_estimators': 396, 'max_depth': 7, 'learning_rate': 0.01590339838385065, 'subsample': 0.7265834538965671, 'colsample_bytree': 0.6400751498648725, 'reg_lambda': 3.552165976797147}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:52:01,215] Trial 25 finished with value: 0.8061321086766902 and parameters: {'n_estimators': 454, 'max_depth': 10, 'learning_rate': 0.006343436600389034, 'subsample': 0.6354009008733341, 'colsample_bytree': 0.7311044953602097, 'reg_lambda': 0.1887365431487371}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:52:01,507] Trial 26 finished with value: 0.8288427510490632 and parameters: {'n_estimators': 319, 'max_depth': 4, 'learning_rate': 0.019353336110674496, 'subsample': 0.7951288044653549, 'colsample_bytree': 0.6026717247708457, 'reg_lambda': 0.5915755029880816}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:52:01,767] Trial 27 finished with value: 0.8281957751297613 and parameters: {'n_estimators': 315, 'max_depth': 3, 'learning_rate': 0.008950038894115192, 'subsample': 0.7852294893835489, 'colsample_bytree': 0.5823473490292325, 'reg_lambda': 0.6106525835684081}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:52:01,983] Trial 28 finished with value: 0.823812741411725 and parameters: {'n_estimators': 151, 'max_depth': 5, 'learning_rate': 0.01904586806598706, 'subsample': 0.7204059564251484, 'colsample_bytree': 0.6125418906134102, 'reg_lambda': 0.12695465524092128}. Best is trial 5 with value: 0.8309305917187679.
# [I 2025-11-23 08:52:02,173] Trial 29 finished with value: 0.8258119670032387 and parameters: {'n_estimators': 235, 'max_depth': 3, 'learning_rate': 0.06523514390032947, 'subsample': 0.6585186756905129, 'colsample_bytree': 0.5488976495605375, 'reg_lambda': 0.0022239325979509675}. Best is trial 5 with value: 0.8309305917187679.

# %%
#Display best score and params
print("Best LogReg Score", study_logreg.best_value)
print("Best LogReg params:", study_logreg.best_params)

print("Best RandomForest Score:", study_rf.best_value)
print("Best RandomForest params:", study_rf.best_params)

print("Best XGB Score", study_xgb.best_value)
print("Best XGB params:", study_xgb.best_params)
# Out:
# Best LogReg Score 0.825861926353544
# Best LogReg params: {'C': 0.0013545772546022356, 'solver': 'lbfgs', 'max_iter': 905}
# Best RandomForest Score: 0.8277452104851277
# Best RandomForest params: {'n_estimators': 281, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 17, 'max_features': 'sqrt'}
# Best XGB Score 0.8309305917187679
# Best XGB params: {'n_estimators': 159, 'max_depth': 3, 'learning_rate': 0.03629251138591226, 'subsample': 0.6827678253594818, 'colsample_bytree': 0.6827280108332846, 'reg_lambda': 0.0070974130672716565}

# %%
scores = {
    'Logistic Regression': study_logreg.best_value,
    'Random Forest': study_rf.best_value,
    'XG Boost': study_xgb.best_value
}

for model, score in scores.items():
    print(f"{model} PR-AUC: {score:.4f}")

best_model = max(scores, key=scores.get)
print('Winning model:', best_model)
# Out:
# Logistic Regression PR-AUC: 0.9391
# Random Forest PR-AUC: 0.9941
# XG Boost PR-AUC: 0.9940
# Winning model: Random Forest

# %%
# Find best params for winning model
rf_best_params = study_rf.best_params

#train winning model
rf_best_params.update({
    'max_samples': None,
    'n_jobs':-1,
    'random_state':42
})

final_rf = RandomForestClassifier(**rf_best_params)
final_rf.fit(X_train_scaled, y_train)

y_proba_test = final_rf.predict_proba(X_test_scaled)[:,1]
y_pred_test = final_rf.predict(X_test_scaled)

test_accuracy = accuracy_score(y_test, y_pred_test)
test_pr_auc = average_precision_score(y_test, y_proba_test)
test_brier = brier_score_loss(y_test, y_proba_test)

# %%
#Display accuracy, average_precision, and brier score
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test PR-AUC: {test_pr_auc:.4f}')
print(f'Brier Score: {test_brier:.4f}')
# Out:
# Test Accuracy: 0.9523
# Test PR-AUC: 0.9927
# Brier Score: 0.0435

# %%
# Generate Feature Importance Ranking
feature_importance = pd.DataFrame({
    'feature':X_train_scaled.columns,
    'importance':final_rf.feature_importances_
    })
feature_importance.sort_values('importance', ascending=False).reset_index(drop=True)
# Out:
#                    feature  importance
# 0       point_differential    0.792807
# 1               close_game    0.061232
# 2            season_FT_pct    0.035442
# 3           overall_ft_pct    0.032404
# 4        seconds_remaining    0.016942
# 5           pressure_score    0.016302
# 6            clutch_ft_pct    0.012235
# 7            clutch_factor    0.010394
# 8                   period    0.008761
# 9   career_attempts_so_far    0.007669
# 10               is_clutch    0.003430
# 11               late_game    0.002382

# %%
# Create confusion matrix
cm = confusion_matrix(y_test, y_pred_test)
ConfusionMatrixDisplay(cm).plot()
plt.title("Confusion Matrix")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# The confusion matrix displays the accuracy of our model. With FT_made=0 being a miss and FT_made=1 being a make, our model had a total 2203 samples with 551 being true negatives, 6 being false positives, 99 being false negatives, and 1547 being true positives. The model holds strong predictive capability  and rarely predicted the wrong result. When the model did predict wrong, it tends to underestimate whether the FT made rather than overestimate whether the FT made when the model was wrong. Overall, the confusion matrix displays the reliability of the model, maintaining an extremely low false-positive rate.

# %%
# Save model as pickle file
pickle.dump(final_rf, open('final_rf.pkl', 'wb'))

#Load model
loaded_model = pickle.load(open('final_rf.pkl', 'rb'))

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba_test)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_proba_test)
plt.subplot(1, 2, 2)
plt.plot(recall, precision, label=f'PR Curve (AP = {test_pr_auc:.3f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(y_test, y_proba_test, n_bins=10)

plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Random Forest')
plt.plot([0, 1], [0, 1], 'k--', label='Perfect Calibration')
plt.xlabel('Mean Predicted Probability')
plt.ylabel('Fraction of Positives')
plt.title('Calibration Curve')
plt.legend()
plt.grid(True)
plt.show()

print(f"Brier Score: {test_brier:.4f}")
print("Lower is better; perfectly calibrated model = 0")
# Out:
# Brier Score: 0.0435
# Lower is better; perfectly calibrated model = 0

# %%
# Find misclassified cases
misclassified_idx = y_test.index[y_test != y_pred_test]
misclassified_data = X_test_scaled.loc[misclassified_idx]

print(f"Total misclassified: {len(misclassified_idx)}")
print(f"False Positives: {(cm[0, 1])} (predicted make, actual miss)")
print(f"False Negatives: {(cm[1, 0])} (predicted miss, actual make)")

# Analyze feature distributions for errors
print("\nFeature averages for misclassified cases:")
print(misclassified_data.describe().loc['mean'])
# Out:
# Total misclassified: 105
# False Positives: 5 (predicted make, actual miss)
# False Negatives: 100 (predicted miss, actual make)
#
# Feature averages for misclassified cases:
# season_FT_pct             0.101207
# overall_ft_pct            0.101207
# clutch_ft_pct             0.027898
# clutch_factor            -0.032694
# career_attempts_so_far    0.262795
# period                    0.328605
# seconds_remaining        -0.132175
# is_clutch                 0.300101
# close_game               -0.527120
# late_game                 0.262020
# pressure_score           -0.060972
# point_differential       -0.148691
# Name: mean, dtype: float64

# %%
# Find misclassified cases
misclassified_idx = y_test.index[y_test != y_pred_test]
misclassified_data = X_test_scaled.loc[misclassified_idx]

print(f"Total misclassified: {len(misclassified_idx)}")
print(f"False Positives: {(cm[0, 1])} (predicted make, actual miss)")
print(f"False Negatives: {(cm[1, 0])} (predicted miss, actual make)")

# Analyze feature distributions for errors
print("\nFeature averages for misclassified cases:")
print(misclassified_data.describe().loc['mean'])
# Out:
# Total misclassified: 105
# False Positives: 5 (predicted make, actual miss)
# False Negatives: 100 (predicted miss, actual make)
#
# Feature averages for misclassified cases:
# season_FT_pct             0.101207
# overall_ft_pct            0.101207
# clutch_ft_pct             0.027898
# clutch_factor            -0.032694
# career_attempts_so_far    0.262795
# period                    0.328605
# seconds_remaining        -0.132175
# is_clutch                 0.300101
# close_game               -0.527120
# late_game                 0.262020
# pressure_score           -0.060972
# point_differential       -0.148691
# Name: mean, dtype: float64
